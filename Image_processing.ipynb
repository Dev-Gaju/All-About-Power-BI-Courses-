# %%
from PIL import Image

# %%
a=Image.open('image.png')

# %%
a
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1067x121 at 0x1E920BEAA88>

# %%
a.size           #first on is width and second on height
# Out:
# (1067, 121)

# %%
a.filename
# Out:
# 'image.png'

# %%
a.format_description
# Out:
# 'Portable network graphics'

# %%
#crop Image

# %%
a.crop((0,0,200,200))   # first two is x and y cordinate and last two is width and height
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x1E920C8C708>

# %%
x = 0
y = 70

w = 1067 / 2
h = 121

# %%
a.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=534x51 at 0x2904ADA87C8>

# %%
skyview= Image.open('skyview.jpg')

# %%
skyview
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x720 at 0x2904944E548>

# %%
skyview.size
# Out:
# (1080, 720)

# %%
x= 0
y= 0

w = 1080/3
h = 720 /10

# %%
skyview.crop((x,y,w,h))       # declare the value of image and crop
# Out:
# <PIL.Image.Image image mode=RGB size=360x72 at 0x2904AA2C1C8>

# %%
skyview.height
# Out:
# 720

# %%
pensils = Image.open('pensils.jpg')

# %%
pensils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x1E920C9BA88>

# %%
pensils.size
# Out:
# (1000, 667)

# %%
x = 0
y = 550

w = 1080 / 3
h = 667

# %%
pensils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=360x117 at 0x1E920A8DAC8>

# %%
pensils.paste(im=pensils, box=(700,300))

# %%
pensils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x1E920C9BA88>

# %%
pensils.resize((500,500))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x2904AC36C88>

# %%
pensils.rotate(40)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x2904A8EC788>

# %%
blue= Image.open('blue.jpg')

# %%
blue.size
# Out:
# (150, 200)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=150x200 at 0x2904D222708>

# %%
red= Image.open('red.jpg')

# %%
red.size
# Out:
# (275, 183)

# %%
red.resize((150,200))
# Out:
# <PIL.Image.Image image mode=RGB size=150x200 at 0x2904D23C6C8>

# %%
red.putalpha(128)

# %% [raw]
# red

# %%
blue.putalpha(240)

# %%
blue

# %%
# red.paste(im=blue, box=(0,0),mask=red)  #can add mask as mask=blue

# %%
# red=red.resize(blue.size)

# %%
red
# Out:
# <PIL.Image.Image image mode=RGBA size=150x200 at 0x2904AF909C8>

# %%
blue.paste(red,(0,0),red)

# %%
a=skyview.resize(red.size)

# %%
a.paste(red,(0,0),red)

# %%
a
# Out:
# <PIL.Image.Image image mode=RGB size=150x200 at 0x2904AE9BF88>
